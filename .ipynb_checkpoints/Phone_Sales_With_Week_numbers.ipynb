# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv(r"marketplace.csv")
df['date'] = pd.to_datetime(df.date)

#Sorting the sales records in the ascending order of dates 
df = df.sort_values(by='date')

# %%
df=df.dropna() # dropping those tuples

# %%
#A dictionary that will contain the unique mobile phone models as keys and their corresponding sales information in the
#form of a dataframe as values
mobile_dict = dict() 


#Getting the list of attributes needed to recreate the sales data dataframe for the individual phone models.
column_list = []
for i in df:
    column_list.append(i)
    

#Creating the dataframes 
for i in df['product_type'].unique():
    mobile_dict[i] = pd.DataFrame(columns=column_list)
  
#Copying information into the dataframes
for i in mobile_dict:
    mobile_dict[i] = df.loc[df['product_type'] == i]
    
# Dropping date as it isn't unifomrly distributed and dropping product_type as it already happens to be 
#the key in the dictionary

for i in mobile_dict.keys():
    for column in mobile_dict[i].columns:
        if column in ['date', 'product_type']:
            del mobile_dict[i][column]

#Appending the week column for each of the dataframes
for i in mobile_dict.keys():
    week = []
    for j in range(1, len(mobile_dict[i]) + 1):
        week.append(str(j))
    
    mobile_dict[i].insert(1, "week", week, True)

# %%
#Just an example to see if everything is going as per the plan
mobile_dict['Huawei nova 5T']
# Out:
#                                                 sku_name week product_id  \
# 0                  HUAWEI NOVA 5T RAM 8GB INTERNAL 128GB    1         E1
# 3395   HUAWEI NOVA 5T RAM 8/128GB GARANSI RESMI HUAWE...    2       E287
# 5417   HUAWEI NOVA 5T RAM 8/128GB GARANSI RESMI HUAWE...    3       F674
# 2      HUAWEI NOVA 5T RAM 8/128 GARANSI RESMI HUAWEI ...    4         F2
# 5421   HUAWEI NOVA 5T RAM 8/128 GARANSI RESMI HUAWEI ...    5       F677
# ...                                                  ...  ...        ...
# 3      HUAWEI NOVA 5T RAM 8/128GB GARANSI RESMI HUAWE...  116         E2
# 14058  HUAWEI NOVA 5T RAM 8/128 GARANSI RESMI HUAWEI ...  117       F677
# 24837  Huawei Nova 5T 8/128 Ram 8gb Rom 128gb Garansi...  118      E3261
# 24833  Huawei Nova 5T 8/128 Ram 8gb Rom 128gb Garansi...  119      E3261
# 14055  HUAWEI NOVA 5T RAM 8/128 GARANSI RESMI HUAWEI ...  120       F677
#
#        merchant_code merchant_badge                    merchant_city    cod  \
# 0                1.0             PM                      Kota Kediri  False
# 3395             4.0             OS                    Kota Surabaya  False
# 5417           876.0             PM  Kota Administrasi Jakarta Barat  False
# 2                3.0             PM  Kota Administrasi Jakarta Barat  False
# 5421           928.0             PM  Kota Administrasi Jakarta Barat  False
# ...              ...            ...                              ...    ...
# 3                4.0             OS                    Kota Surabaya  False
# 14058          928.0             PM  Kota Administrasi Jakarta Barat  False
# 24837          801.0             OS  Kota Administrasi Jakarta Pusat  False
# 24833          801.0             OS  Kota Administrasi Jakarta Pusat  False
# 14055          928.0             PM  Kota Administrasi Jakarta Barat  False
#
#          price  stock  daily_gmv  daily_sold  daily_view  rating  \
# 0      4500000      1          0           0           0      95
# 3395   4698500      6          0           0           0      98
# 5417   4589900   9984          0           0           0      99
# 2      4589900     16          0           0           0      96
# 5421   4579000      1          0           0         252      96
# ...        ...    ...        ...         ...         ...     ...
# 3      4698500      5          0           0           0      99
# 14058  4749000     19          0           0           0      96
# 24837  4800000     13   14400000           3         844      98
# 24833  4800000     13          0           0           0      98
# 14055  4849000     19          0           0         127      96
#
#        total_review  total_sold
# 0                37          74
# 3395             30          48
# 5417             30          59
# 2                12          19
# 5421             20          38
# ...             ...         ...
# 3                42          63
# 14058            31          58
# 24837           174         326
# 24833           174         326
# 14055            31          58
#
# [120 rows x 15 columns]

# %%
#To see the variation of total_sold for Huawei nova 5T on a weekly basis
plt.plot(mobile_dict['Huawei nova 5T']['week'], mobile_dict['Huawei nova 5T']['total_sold'])
